# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('googleplaystore.csv')

# %%
# set the options to show meximum row and column 
pd.set_option("display.max_columns", None)
pd.set_option("display.max_row", None)
# hide the all warning 
import warnings
warnings.filterwarnings('ignore')

# %%
print(f"The name of columns {df.columns}")
# Out:
# The name of columns Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Size_MB'],
#       dtype='object')

# %%
# print the number of row and column 
print(f" Number of row {df.shape[0]} and number of columns {df.shape[1]}")
# Out:
#  Number of row 10841 and number of columns 14

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  int64
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10839 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.1+ MB

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews                Size     Installs  Type Price  \
# 10836     4.5       38                 53M       5,000+  Free     0
# 10837     5.0        4                3.6M         100+  Free     0
# 10838     NaN        3                9.5M       1,000+  Free     0
# 10839     4.5      114  Varies with device       1,000+  Free     0
# 10840     4.5   398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
df.sample(2)
# Out:
#                                      App       Category  Rating  Reviews  \
# 4518  ICQ — Video Calls & Chat Messenger  COMMUNICATION     4.4   697939
# 1153                    NetSpend Prepaid        FINANCE     4.2    15993
#
#                     Size     Installs  Type Price Content Rating  \
# 4518  Varies with device  10,000,000+  Free     0       Everyone
# 1153                 45M   1,000,000+  Free     0       Everyone
#
#              Genres   Last Updated  Current Ver Android Ver
# 4518  Communication  July 18, 2018  7.3(823181)  4.4 and up
# 1153        Finance    May 9, 2018       4.10.0  4.4 and up

# %%
df.describe()
# Out:
#             Rating       Reviews
# count  9367.000000  1.084100e+04
# mean      4.191513  4.441119e+05
# std       0.515735  2.927629e+06
# min       1.000000  0.000000e+00
# 25%       4.000000  3.800000e+01
# 50%       4.300000  2.094000e+03
# 75%       4.500000  5.476800e+04
# max       5.000000  7.815831e+07

# %% [markdown]
# # all numric variable make the numaric
# 1- Size
# 2-Installs
# 3-Price

# %%
#check the unique 
df['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
df['Price'] = df['Price'].str.replace('$', '', regex=False).astype(float)

# %%
df['Price'].unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   1.49,   2.99,   7.99,   5.99,
#          3.49,   1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,
#         24.99,  11.99,  79.99,  16.99,  14.99,   1.  ,  29.99,  12.99,
#          2.49,  10.99,   1.5 ,  19.99,  15.99,  33.99,  74.99,  39.99,
#          3.95,   4.49,   1.7 ,   8.99,   2.  ,   3.88,  25.99, 399.99,
#         17.99, 400.  ,   3.02,   1.76,   4.84,   4.77,   1.61,   2.5 ,
#          1.59,   6.49,   1.29,   5.  ,  13.99, 299.99, 379.99,  37.99,
#         18.99, 389.99,  19.9 ,   8.49,   1.75,  14.  ,   4.85,  46.99,
#        109.99, 154.99,   3.08,   2.59,   4.8 ,   1.96,  19.4 ,   3.9 ,
#          4.59,  15.46,   3.04,   4.29,   2.6 ,   3.28,   4.6 ,  28.99,
#          2.95,   2.9 ,   1.97, 200.  ,  89.99,   2.56,  30.99,   3.61,
#        394.99,   1.26,   1.2 ,   1.04])

# %%
df['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
df['Size'].value_counts()
# Out:
# Size
# Varies with device    1695
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
#                       ...
# 253k                     1
# 992k                     1
# 658k                     1
# 73k                      1
# 246k                     1
# Name: count, Length: 461, dtype: int64

# %%
def convert_size(value):
    if value == 'Varies with device':
        return np.nan  # or use None to remove later
    elif value.endswith('M'):
        return float(value.replace('M', ''))
    elif value.endswith('k'):
        return round(float(value.replace('k', '')) / 1024, 2)
    else:
        return np.nan

# %%
df['Size_MB'] = df['Size'].apply(convert_size)

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type  Price Content Rating  \
# 0      159   19M      10,000+  Free    0.0       Everyone
# 1      967   14M     500,000+  Free    0.0       Everyone
# 2    87510  8.7M   5,000,000+  Free    0.0       Everyone
# 3   215644   25M  50,000,000+  Free    0.0           Teen
# 4      967  2.8M     100,000+  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.describe()
# Out:
#             Rating       Reviews         Price     Size_MB
# count  9367.000000  1.084100e+04  10841.000000  9146.00000
# mean      4.191513  4.441119e+05      1.027273    21.51415
# std       0.515735  2.927629e+06     15.948971    22.58867
# min       1.000000  0.000000e+00      0.000000     0.01000
# 25%       4.000000  3.800000e+01      0.000000     4.90000
# 50%       4.300000  2.094000e+03      0.000000    13.00000
# 75%       4.500000  5.476800e+04      0.000000    30.00000
# max       5.000000  7.815831e+07    400.000000   100.00000

# %%
#install columns convert and check
df['Installs'].nunique()
# Out:
# 21

# %%
df['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
df['Installs'].value_counts()
# Out:
# Installs
# 1,000,000+        1579
# 10,000,000+       1252
# 100,000+          1169
# 10,000+           1054
# 1,000+             908
# 5,000,000+         752
# 100+               719
# 500,000+           539
# 50,000+            479
# 5,000+             477
# 100,000,000+       409
# 10+                386
# 500+               330
# 50,000,000+        289
# 50+                205
# 5+                  82
# 500,000,000+        72
# 1+                  67
# 1,000,000,000+      58
# 0+                  14
# 0                    1
# Name: count, dtype: int64

# %%
# remove "+" and "," in my Installs
df['Installs'] = df['Installs'].apply(lambda x: x.replace("+", "") if '+' in str(x) else x)

# %%
df['Installs'] = df['Installs'].apply(lambda x: x.replace(",", "") if ',' in str(x) else x)

# %%
df['Installs'].value_counts()
# Out:
# Installs
# 1000000       1579
# 10000000      1252
# 100000        1169
# 10000         1054
# 1000           908
# 5000000        752
# 100            719
# 500000         539
# 50000          479
# 5000           477
# 100000000      409
# 10             386
# 500            330
# 50000000       289
# 50             205
# 5               82
# 500000000       72
# 1               67
# 1000000000      58
# 0               15
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#             Rating       Reviews         Price     Size_MB
# count  9367.000000  1.084100e+04  10841.000000  9146.00000
# mean      4.191513  4.441119e+05      1.027273    21.51415
# std       0.515735  2.927629e+06     15.948971    22.58867
# min       1.000000  0.000000e+00      0.000000     0.01000
# 25%       4.000000  3.800000e+01      0.000000     4.90000
# 50%       4.300000  2.094000e+03      0.000000    13.00000
# 75%       4.500000  5.476800e+04      0.000000    30.00000
# max       5.000000  7.815831e+07    400.000000   100.00000

# %%
# we convert install into intiger
df['Installs'] = df['Installs'].apply(lambda x: int(x))

# %%
df.describe()
# Out:
#             Rating       Reviews      Installs         Price     Size_MB
# count  9367.000000  1.084100e+04  1.084100e+04  10841.000000  9146.00000
# mean      4.191513  4.441119e+05  1.546291e+07      1.027273    21.51415
# std       0.515735  2.927629e+06  8.502557e+07     15.948971    22.58867
# min       1.000000  0.000000e+00  0.000000e+00      0.000000     0.01000
# 25%       4.000000  3.800000e+01  1.000000e+03      0.000000     4.90000
# 50%       4.300000  2.094000e+03  1.000000e+05      0.000000    13.00000
# 75%       4.500000  5.476800e+04  5.000000e+06      0.000000    30.00000
# max       5.000000  7.815831e+07  1.000000e+09    400.000000   100.00000

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             1
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               1
# Last Updated         0
# Current Ver          8
# Android Ver          2
# Size_MB           1695
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >
