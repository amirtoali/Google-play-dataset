# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df =  sns.load_dataset("titanic")

# %%
df.plot(kind="scatter", x='age', y='fare', color='red')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
df.groupby('sex')['fare'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='sex'>

# %%
sns.barplot(data=df, x='sex' , y = 'fare', hue='class')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
import plotly.express as px
import plotly.io

# %%
pip install nbformat --upgrade
# Out:
# Requirement already satisfied: nbformat in /usr/local/Caskroom/miniconda/base/envs/google_play/lib/python3.10/site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/Caskroom/miniconda/base/envs/google_play/lib/python3.10/site-packages (from nbformat) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/Caskroom/miniconda/base/envs/google_play/lib/python3.10/site-packages (from nbformat) (4.25.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/Caskroom/miniconda/base/envs/google_play/lib/python3.10/site-packages (from nbformat) (5.8.1)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/Caskroom/miniconda/base/envs/google_play/lib/python3.10/site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/Caskroom/miniconda/base/envs/google_play/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/Caskroom/miniconda/base/envs/google_play/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/Caskroom/miniconda/base/envs/google_play/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/Caskroom/miniconda/base/envs/google_play/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat) (0.26.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/Caskroom/miniconda/base/envs/google_play/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.3.8)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/Caskroom/miniconda/base/envs/google_play/lib/python3.10/site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat) (4.14.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
fig = px.scatter(df, x='age' , y = 'fare', color='class')

# %%
import plotly.io as pio
pio.renderers.default = 'browser'  # Opens in web browser

# Now show the figure
fig.show()

# %%
plt.figure(figsize=(5, 8))
sns.scatterplot(data = df, x='age', y='fare', hue='sex' )
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.boxenplot(data = df, x='sex', y='age' , hue ='class')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
fig = px.sunburst(df, path=['sex', 'class','who', 'alive', 'alone'],
                  values='survived', color='sex')

# %%
fig.show()
# Out:
# python(43060) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df_1 = px.data.gapminder()

# %%
df_1
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# 3           4
# 4           4
# ...       ...
# 1699      716
# 1700      716
# 1701      716
# 1702      716
# 1703      716
#
# [1704 rows x 8 columns]

# %%
fig = px.sunburst(df_1, path=['continent', 'country','year'],
                  values='pop', color='continent')

# %%
fig.show()
# Out:
# python(43327) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
